# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnaqwerty/fishAddOns/blob/main/fishTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import google.generativeai as genai

genai.configure(api_key="AIzaSyBJnE4HIFBI18-K01HlajZQOyNPUc6xvK0")

generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="tunedModels/spamfilter-uhtynq0ej87q",
  generation_config=generation_config,
)

chat_session = model.start_chat(
  history=[
    {
      "role": "user",
      "parts": [
        "WARNING:tornado.access:400 POST /v1beta/models/SpamFilter:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 4067.64ms\n---------------------------------------------------------------------------\nBadRequest                                Traceback (most recent call last)\n<ipython-input-1-236bf0796ee5> in <cell line: 0>()\n     11 \n     12 # Test the fine-tuned model with a prompt\n---> 13 response = model.generate_content(\"Subject: jennifer sends them to their final destination . designated as a private key 4 . validate public keys . someone wants to meet you ! who your match could be , find here to the purported owner . you \")\n     14 \n     15 # Print the model's response\n\n9 frames\n/usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)\n   1159             # subclass.\n   1160             if response.status_code >= 400:\n-> 1161                 raise core_exceptions.from_http_response(response)\n   1162 \n   1163             # Return the response\n\nBadRequest: 400 POST https://generativelanguage.googleapis.com/v1beta/models/SpamFilter:generateContent?%24alt=json%3Benum-encoding%3Dint: * GenerateContentRequest.model: unexpected model name format\n\n",
      ],
    },
    {
      "role": "model",
      "parts": [
        "The error message \"ham",
      ],
    },
    {
      "role": "user",
      "parts": [
        "Subject: jennifer\nsends them to their final destination .\ndesignated as a private key\n4 . validate public keys .\nsomeone wants to meet you !\nwho your match could be , find here\nto the purported owner . you\n",
      ],
    },
    {
      "role": "model",
      "parts": [
        "spam",
      ],
    },
    {
      "role": "user",
      "parts": [
        "Subject: calpine daily gas nomination\n>\n>\njulie , as i mention earlier we hope to start the unit this afternoon but\nare still experiencing difficulties . i will keep you informed . thanks .\nricky a . archer\nfuel supply\n700 louisiana , suite 2700\nhouston , texas 77002\n713 - 830 - 8659 direct\n713 - 830 - 8722 fax\n- calpine daily gas nomination 1 . doc\n- calpine daily gas nomination 1 . doc",
      ],
    },
    {
      "role": "model",
      "parts": [
        "spam",
      ],
    },
  ]
)


response = chat_session.send_message("Subject: jennifer sends them to their final destination . designated as a private key 4 . validate public keys . someone wants to meet you ! who your match could be , find here to the purported owner . you ")

print(response.text)
# Out:
# spam

# %%
import pandas as pd

# %%
df = pd.read_csv("dataTest.csv")
df.shape
# Out:
# (5171, 4)

# %%
new_df = df.head(100)
new_df.shape
# Out:
# (100, 4)

# %%
new_df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
new_df = new_df[['text', 'label']]
new_df.shape
# Out:
# (100, 2)

# %%
import time
 # Ensure this file exists with 'text' & 'label' columns

actual_labels = []
predicted_labels = []

batch_size = 10  # Max requests per batch
batch_delay = 60  # Time to wait between batches (in seconds)

# Process the dataset in batches of 10 emails
for i in range(0, len(new_df), batch_size):
    batch = new_df.iloc[i:i + batch_size]  # Get a batch of 10 rows

    for email in batch["text"]:
        response = model.generate_content(email)  # Get model's response

        # Convert model output to standardized label
        prediction = response.text.strip().lower()
        if "spam" in prediction:
            predicted_labels.append("spam")
            print("Warning! Potential Threat")
        else:
            predicted_labels.append("ham")
            print("Safe !")

    # Append actual labels from batch
    actual_labels.extend(batch["label"].tolist())

    # Wait 60 seconds after processing 10 requests to stay within API limits
    if i + batch_size < len(df):  # Don't wait after the last batch
        print(f"Waiting {batch_delay} seconds before sending next batch...")
        time.sleep(batch_delay)

# Compute accuracy
accuracy = accuracy_score(actual_labels, predicted_labels)

# Print results
print(f"Model Accuracy: {accuracy:.2%}\n")
print("Classification Report:\n", classification_report(actual_labels, predicted_labels))
# Out:
# Safe !
# Safe !
# Safe !
# Warning! Potential Threat
# Safe !
# Safe !
# Warning! Potential Threat
# Warning! Potential Threat
# Safe !
# Safe !
# Waiting 60 seconds before sending next batch...
# Warning! Potential Threat
# Warning! Potential Threat
# Safe !
# Warning! Potential Threat
# Safe !
# Warning! Potential Threat
# Safe !
# Safe !
# Safe !
# Safe !
# Waiting 60 seconds before sending next batch...
# Safe !
# Safe !
# Safe !
# Safe !
# Warning! Potential Threat
# Safe !
# Warning! Potential Threat
# Safe !
# Safe !
# Safe !
# Waiting 60 seconds before sending next batch...
# Safe !
# Safe !
# Safe !
# Safe !
# Safe !
# Warning! Potential Threat
# Safe !
# Safe !
# Safe !
# Safe !
# Waiting 60 seconds before sending next batch...
# Warning! Potential Threat
# Warning! Potential Threat
# Safe !
# Safe !
# Safe !
# Safe !
# Warning! Potential Threat
# Warning! Potential Threat
# Warning! Potential Threat
# Warning! Potential Threat
# ...
